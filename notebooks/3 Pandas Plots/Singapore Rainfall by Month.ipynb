# %%
import pandas as pd
df = pd.read_csv('rainfall-monthly-total.csv')
df
# Out:
#        month  total_rainfall
# 0    1982-01           107.1
# 1    1982-02            27.8
# 2    1982-03           160.8
# 3    1982-04           157.0
# 4    1982-05           102.2
# ..       ...             ...
# 457  2020-02            65.0
# 458  2020-03           108.8
# 459  2020-04           188.0
# 460  2020-05           255.6
# 461  2020-06           233.8
#
# [462 rows x 2 columns]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df.plot(x='month', kind='line', figsize=(15,6))
